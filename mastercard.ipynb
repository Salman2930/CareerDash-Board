# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup as sk
import json

url = 'https://www.epam.com/services/vacancy/search?locale=en&limit=20&recruitingUrl=%2Fcontent%2Fepam%2Fen%2Fcareers%2Fjob-listings%2Fjob&query=&country=India&sort=relevance&offset=40&searchType=placeOfWorkFilter&_=1675779201706'
r = requests.get(url)
job = r.json()
print(job)


# for jobs in job:
#     print()
# Out:
# {'result': [{'urgent': True, 'relocation': True, 'remote': False, 'office': True, 'continuum': False, 'localizedGroup': 'Software, System, and Test Engineering', 'isGdo': False, 'hideCityOnPage': False, 'id': 85577, 'name': 'Open Source Technology - Lead Engineer (Core Java, AWS, DS Algo)', 'language': 'en', 'internationalCountry': 'India', 'internationalCity': 'Bangalore', 'localizedCity': 'Bangalore', 'localizedCountry': 'India', 'displayedLocation': 'Bangalore, India', 'description': 'EPAM is a leading global provider of digital platform engineering and development services. We are committed to having a positive impact on our customers, our employees, and our communities. We embrace a dynamic and inclusive culture. Here you will collaborate with multi-national teams, contribute to a myriad of innovative projects that deliver the most creative and cutting-edge solutions, and have an opportunity to continuously learn and grow. No matter where you are located, you will join a dedicated, creative, and diverse community that will help you discover your fullest potential.<br/><br/>EPAM’s global multi-disciplinary teams serve 61,600 employees and customers in more than 45 countries across five continents.<br/><br/>As a recognized leader, EPAM is listed among the top 15 companies in Information Technology Services on the Fortune 1000 and ranked as the top IT services company on Fortune’s 100 Fastest-Growing Companies list for the last three consecutive years.<br/><br/>EPAM is also listed among Ad Age’s top 25 World’s Largest Agency Companies and in 2020, Consulting Magazine named EPAM Continuum a top 20 Fastest-Growing.', 'shortDescription': 'EPAM is a leading global provider of digital platform engineering and development services. We are committed to having a positive impact on our customers, our employees, and our communities. We embrace a dynamic and inclusive...', 'url': 'https://www.epam.com/careers/job-listings/job.85577.open-source-technology-lead-engineer-core-java-aws-ds-algo_bangalore_india'}, {'urgent': True, 'relocation': True, 'remote': False, 'office': True, 'continuum': False, 'localizedGroup': 'Software, System, and Test Engineering', 'isGdo': False, 'hideCityOnPage': False, 'id': 85575, 'name': 'Open Source Technology - Lead Engineer (Core Java, AWS, DS Algo)', 'language': 'en', 'internationalCountry': 'India', 'internationalCity': 'Hyderabad', 'localizedCity': 'Hyderabad', 'localizedCountry': 'India', 'displayedLocation': 'Hyderabad, India', 'description': 'EPAM is a leading global provider of digital platform engineering and development services. We are committed to having a positive impact on our customers, our employees, and our communities. We embrace a dynamic and inclusive culture. Here you will collaborate with multi-national teams, contribute to a myriad of innovative projects that deliver the most creative and cutting-edge solutions, and have an opportunity to continuously learn and grow. No matter where you are located, you will join a dedicated, creative, and diverse community that will help you discover your fullest potential.<br/><br/>EPAM’s global multi-disciplinary teams serve 61,600 employees and customers in more than 45 countries across five continents.<br/><br/>As a recognized leader, EPAM is listed among the top 15 companies in Information Technology Services on the Fortune 1000 and ranked as the top IT services company on Fortune’s 100 Fastest-Growing Companies list for the last three consecutive years.<br/><br/>EPAM is also listed among Ad Age’s top 25 World’s Largest Agency Companies and in 2020, Consulting Magazine named EPAM Continuum a top 20 Fastest-Growing.', 'shortDescription': 'EPAM is a leading global provider of digital platform engineering and development services. We are committed to having a positive impact on our customers, our employees, and our communities. We embrace a dynamic and inclusive...', 'url': 'https://www.epam.com/careers/job-listings/job.85575.open-source-technolo ...

# %%
final_data = []
for cat in job['result']:
    content = {}
    content['Company Name'] = 'EPAM'
    content['Job Title'] = cat['name']
    content['Location'] = cat['localizedCity']
    content['Apply Here'] = cat['url']
    final_data.append(content)
epam_df_data = pd.DataFrame(final_data)
epam_df_data
epam_df_data.to_excel('epam jobs.xlsx' , index = False)
